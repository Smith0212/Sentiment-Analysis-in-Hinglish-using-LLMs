# %%
#read final_dataset_hinglish.csv 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd
import matplotlib.pyplot as plt

data=pd.read_csv("data_with_all_sentiment.csv")

color_map = {
    "positive": "green",
    "neutral": "blue",
    "negative": "red",
    "": "gray"  
}

def plot_pie_chart(ax, column):
    counts = df[column].value_counts()
    labels = counts.index
    sizes = counts.values
    colors = [color_map[label] for label in labels]
    ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140, colors=colors)
    ax.set_title(f'Sentiment Distribution for {column}')

sentiment_columns = ["twitter_roberta", "beto_sentiment", "vader_sentiment", "bert_base", "bart_sentiment"]

fig, axes = plt.subplots(1, len(sentiment_columns), figsize=(20, 6))

for ax, column in zip(axes, sentiment_columns):
    plot_pie_chart(ax, column)

plt.tight_layout()
plt.show()
